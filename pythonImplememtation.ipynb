# %%
# !pip install langchain_community

# %%
# import ollama 
from langchain_community.llms import Ollama

# %%
# Initialize the Ollama model
m = Ollama(model = 'tinyllama')

# Generate the text with the model 
response = m.generate(["When did India got its Independence?"])

print(response)
# Out:
# C:\Users\himu23\AppData\Local\Temp\ipykernel_18300\1265553578.py:2: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import OllamaLLM``.
#   m = Ollama(model = 'tinyllama')
# generations=[[GenerationChunk(text="India got its Independence on August 15, 1947. The Indian independence movement and the events leading up to this date had been brewing for decades. The British colonial government in India was planning to transfer power to a more autocratic form of government with an elected prime minister. This move would have resulted in greater political stability and control by India, while allowing for more freedom and individual liberties within the country. However, this plan was met with widespread opposition from Indians, who were fighting for their right to self-determination and an end to British rule. The Indian independence movement began to gain momentum during the last year of British rule in India, which led up to India's Independence Day.", generation_info={'model': 'tinyllama', 'created_at': '2025-10-29T02:12:59.6761774Z', 'response': '', 'done': True, 'done_reason': 'stop', 'context': [529, 29989, 5205, 29989, 29958, 13, 3492, 526, 263, 8444, 319, 29902, 20255, 29889, 2, 29871, 13, 29966, 29989, 1792, 29989, 29958, 13, 10401, 1258, 7513, 2355, 967, 28052, 663, 29973, 2, 29871, 13, 29966, 29989, 465, 22137, 29989, 29958, 13, 2568, 423, 2355, 967, 28052, 663, 373, 3111, 29871, 29896, 29945, 29892, 29871, 29896, 29929, 29946, 29955, 29889, 450, 7560, 21820, 10298, 322, 278, 4959, 8236, 701, 304, 445, 2635, 750, 1063, 2078, 16958, 363, 1602, 3076, 29889, 450, 4908, 25539, 5874, 297, 7513, 471, 18987, 304, 6782, 3081, 304, 263, 901, 4469, 26844, 2034, 29883, 883, 310, 5874, 411, 385, 11467, 6019, 11050, 29889, 910, 4337, 723, 505, 20601, 297, 7621, 8604, 25806, 322, 2761, 491, 7513, 29892, 1550, 14372, 363, 901, 16082, 322, 5375, 17176, 583, 2629, 278, 4234, 29889, 2398, 29892, 445, 3814, 471, 1539, 411, 9377, 17703, 328, 19626, 515, 17072, 29892, 1058, 892, 17770, 363, 1009, 1492, 304, 1583, 29899, 4801, 837, 3381, 322, 385, 1095, 304, 4908, 5751, 29889, 450, 7560, 21820, 10298, 4689, 304, 11581, 19399, 2645, 278, 1833, 1629, 310, 4908, 5751, 297, 7513, 29892, 607, 5331, 701, 304, 7513, 29915, 29879, 28052, 663, 8373, 29889], 'total_duration': 5098239100, 'load_duration': 105369000, 'prompt_eval_count': 42, 'prompt_eval_duration': 536776900, 'eval_count': 155, 'eval_duration': 4251568500})]] llm_output=None run=[RunInfo(run_id=UUID('c8d2184f-18ea-4fa9-b10d-80e8e3a63d26'))] type='LLMResult'

# %%
response.generations[0][0].text
# Out:
# "India got its Independence on August 15, 1947. The Indian independence movement and the events leading up to this date had been brewing for decades. The British colonial government in India was planning to transfer power to a more autocratic form of government with an elected prime minister. This move would have resulted in greater political stability and control by India, while allowing for more freedom and individual liberties within the country. However, this plan was met with widespread opposition from Indians, who were fighting for their right to self-determination and an end to British rule. The Indian independence movement began to gain momentum during the last year of British rule in India, which led up to India's Independence Day."

# %% [markdown]
# ## Using the entire PDF as context

# %% [markdown]
# If we try to invoke the chain using the PDF as context, the model will return an error because the cntext is too long.
#
# Lagre Language Models support limited context size. The video we are using is too long for the model to handle, so we need to find a different solution.

# %%
# First, install/upgrade langchain
# !pip install -U langchain langchain-openai
# !pip install pypdf  # for PDF processing

# %%
# !pip install openai
# !pip install langchain
# !pip install langchain_community
# !pip install tiktoken
# !pip install faiss-cpu
# !pip install langchain-pinecone
# !pip install pypdf
# !pip install langchain-openai openai

# %%
# importing necessary libraries
import openai  # Base OpenAI package
from langchain_community.document_loaders import PyPDFLoader
from langchain_openai import OpenAIEmbeddings
# New, correct import
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_openai import OpenAI # LangChain's OpenAI wrapper

# %%
# Configure the baseline configuration of the OpenAI library for Azure OpenAI service.
llm = OpenAI(openai_api_key= "!")

# %%
llm.invoke("What is EDA?")
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# /tmp/ipython-input-3692257298.py in <cell line: 0>()
# ----> 1 llm.invoke("What is EDA?")
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/llms.py in invoke(self, input, config, stop, **kwargs)
#     376         config = ensure_config(config)
#     377         return (
# --> 378             self.generate_prompt(
#     379                 [self._convert_input(input)],
#     380                 stop=stop,
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/llms.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     787     ) -> LLMResult:
#     788         prompt_strings = [p.to_string() for p in prompts]
# --> 789         return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#     790
#     791     @override
#
# ...
